# %% [markdown]
# PURPOSE OF THIS NOTEBOOK
# This notebook is to check if the model is actually detecting fraud or not.

# %%
import joblib
from scipy.sparse import load_npz
# Save trained model
model=joblib.load("../models/logistic_regression.pkl")

# %%
X_train_final = load_npz("../data/processed/X_train_final.npz")
X_test_final = load_npz("../data/processed/X_test_final.npz")

y_train = np.load("../data/processed/y_train.npy")
y_test = np.load("../data/processed/y_test.npy")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 X_train_final = load_npz("../data/processed/X_train_final.npz")
#       2 X_test_final = load_npz("../data/processed/X_test_final.npz")
#       4 y_train = np.load("../data/processed/y_train.npy")
#
# NameError: name 'load_npz' is not defined

# %%
y_pred=model.predict(X_test_final)
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 y_pred=model.predict(X_test_final)
#       2 cm=confusion_matrix(y_test,y_pred)
#       3 cm
#
# NameError: name 'X_test_final' is not defined
