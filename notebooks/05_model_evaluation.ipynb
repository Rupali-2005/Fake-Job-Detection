# %% [markdown]
# PURPOSE OF THIS NOTEBOOK
# This notebook is to check if the model is actually detecting fraud or not.

# %%
import joblib
from scipy.sparse import load_npz
import numpy as np
# Save trained model
model=joblib.load("../models/logistic_regression.pkl")

# %%
X_train_final = load_npz("../data/processed/X_train_final.npz")
X_test_final = load_npz("../data/processed/X_test_final.npz")

y_train = np.load("../data/processed/y_train.npy")
y_test = np.load("../data/processed/y_test.npy")

# %%
from sklearn.metrics import confusion_matrix
y_pred=model.predict(X_test_final)
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[3298,  105],
#        [  15,  158]])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98      3403
#            1       0.60      0.91      0.72       173
#
#     accuracy                           0.97      3576
#    macro avg       0.80      0.94      0.85      3576
# weighted avg       0.98      0.97      0.97      3576

# %%
from sklearn.metrics import f1_score,precision_score, recall_score
precision = precision_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
f1 = f1_score(y_test,y_pred)
precision, f1,recall
# Out:
# (0.6007604562737643, 0.7247706422018348, 0.9132947976878613)

# %%
from sklearn.metrics import classification_report

# Training performance
y_train_pred = model.predict(X_train_final)
print("TRAIN METRICS")
print(classification_report(y_train, y_train_pred))

# Test performance
print("TEST METRICS")
print(classification_report(y_test, y_pred))
# Out:
# TRAIN METRICS
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     13611
#            1       0.62      1.00      0.76       693
#
#     accuracy                           0.97     14304
#    macro avg       0.81      0.98      0.87     14304
# weighted avg       0.98      0.97      0.97     14304
#
# TEST METRICS
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98      3403
#            1       0.60      0.91      0.72       173
#
#     accuracy                           0.97      3576
#    macro avg       0.80      0.94      0.85      3576
# weighted avg       0.98      0.97      0.97      3576
